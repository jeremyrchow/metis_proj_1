# %%
import pandas as pd
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
compiled_data_directory = '../../../proj1_unsorted_data/compiled_data_unsorted.csv'
df=pd.read_csv(compiled_data_directory, header=0, names = ["index","ca","remote_unit",\
               "scp_address","station","line_name","division","date","time",\
               "description","entry_cumulative","exit_cumulative"])

# %%
df.head()
# Out:
#    index    ca remote_unit scp_address station line_name division        date  \
# 0      0  A002        R051    02-00-00   59 ST   NQR456W      BMT  04/08/2017
# 1      1  A002        R051    02-00-00   59 ST   NQR456W      BMT  04/08/2017
# 2      2  A002        R051    02-00-00   59 ST   NQR456W      BMT  04/08/2017
# 3      3  A002        R051    02-00-00   59 ST   NQR456W      BMT  04/08/2017
# 4      4  A002        R051    02-00-00   59 ST   NQR456W      BMT  04/08/2017
#
#        time description  entry_cumulative  exit_cumulative
# 0  00:00:00     REGULAR           6127245          2076158
# 1  04:00:00     REGULAR           6127285          2076165
# 2  08:00:00     REGULAR           6127304          2076196
# 3  12:00:00     REGULAR           6127409          2076284
# 4  16:00:00     REGULAR           6127654          2076350

# %%
df2=pd.read_pickle('./turnstyle_df.zip', compression='zip')
df2.head()
# Out:
#    index scp_address station line_name        date      time description  \
# 0      0    02-00-00   59 ST   NQR456W  04/08/2017  00:00:00     REGULAR
# 1      1    02-00-00   59 ST   NQR456W  04/08/2017  04:00:00     REGULAR
# 2      2    02-00-00   59 ST   NQR456W  04/08/2017  08:00:00     REGULAR
# 3      3    02-00-00   59 ST   NQR456W  04/08/2017  12:00:00     REGULAR
# 4      4    02-00-00   59 ST   NQR456W  04/08/2017  16:00:00     REGULAR
#
#    entry_cumulative  exit_cumulative  entry_relative  exit_relative
# 0           6127245          2076158             NaN            NaN
# 1           6127285          2076165            40.0            7.0
# 2           6127304          2076196            19.0           31.0
# 3           6127409          2076284           105.0           88.0
# 4           6127654          2076350           245.0           66.0

# %%
# df.to_pickle('turnstyle_df_3.pkl',protocol = 3)

# %%
df=df.drop(columns = ['ca','remote_unit','division'])

# %%
df['date'] = pd.to_datetime(df['date'],format = '%m/%d/%Y')

# %%
df['time'] = pd.to_datetime(df['time'],format = '%H:%M:%S')
df.head()
# Out:
#    index scp_address station line_name       date                time  \
# 0      0    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 00:00:00
# 1      1    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 04:00:00
# 2      2    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 08:00:00
# 3      3    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 12:00:00
# 4      4    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 16:00:00
#
#   description  entry_cumulative  exit_cumulative  entry_relative  \
# 0     REGULAR           6127245          2076158             NaN
# 1     REGULAR           6127285          2076165            40.0
# 2     REGULAR           6127304          2076196            19.0
# 3     REGULAR           6127409          2076284           105.0
# 4     REGULAR           6127654          2076350           245.0
#
#    exit_relative
# 0            NaN
# 1            7.0
# 2           31.0
# 3           88.0
# 4           66.0

# %%
df.head()
# Out:
#    index scp_address station line_name       date                time  \
# 0      0    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 00:00:00
# 1      1    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 04:00:00
# 2      2    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 08:00:00
# 3      3    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 12:00:00
# 4      4    02-00-00   59 ST   NQR456W 2017-04-08 1900-01-01 16:00:00
#
#   description  entry_cumulative  exit_cumulative  entry_relative  \
# 0     REGULAR           6127245          2076158             NaN
# 1     REGULAR           6127285          2076165            40.0
# 2     REGULAR           6127304          2076196            19.0
# 3     REGULAR           6127409          2076284           105.0
# 4     REGULAR           6127654          2076350           245.0
#
#    exit_relative
# 0            NaN
# 1            7.0
# 2           31.0
# 3           88.0
# 4           66.0

# %%
df['entry_relative'] = df['entry_cumulative'].diff()
df['exit_relative'] = df['exit_cumulative'].diff()

# %%
df['description'].nunique()
# Out:
# 2

# %%
df['entry_relative'].describe()
df.head()
# Out:
#    index scp_address station line_name        date      time description  \
# 0      0    02-00-00   59 ST   NQR456W  04/08/2017  00:00:00     REGULAR
# 1      1    02-00-00   59 ST   NQR456W  04/08/2017  04:00:00     REGULAR
# 2      2    02-00-00   59 ST   NQR456W  04/08/2017  08:00:00     REGULAR
# 3      3    02-00-00   59 ST   NQR456W  04/08/2017  12:00:00     REGULAR
# 4      4    02-00-00   59 ST   NQR456W  04/08/2017  16:00:00     REGULAR
#
#    entry_cumulative  exit_cumulative  entry_relative  exit_relative
# 0           6127245          2076158             NaN            NaN
# 1           6127285          2076165            40.0            7.0
# 2           6127304          2076196            19.0           31.0
# 3           6127409          2076284           105.0           88.0
# 4           6127654          2076350           245.0           66.0

# %%
# df['entry_relative'].plot()

# %%
sus_index=df.loc[df['entry_relative']==df['entry_relative'].max()]
sus_index
# Out:
#          index scp_address station line_name        date      time  \
# 1248069  53458    01-03-00   14 ST      ACEL  03/18/2017  01:00:00
#
#         description  entry_cumulative  exit_cumulative  entry_relative  \
# 1248069     REGULAR        2130581192       1157476857    2.123318e+09
#
#          exit_relative
# 1248069   1.148523e+09

# %%
# Find where turnstile addresses don't match so that diff() function won't be applied there

sus_index_num=1248069
df.iloc[sus_index_num-3:sus_index_num+3]
# Out:
#           index scp_address          station     line_name        date  \
# 0             0    02-00-00            59 ST       NQR456W  04/08/2017
# 1             1    02-00-00            59 ST       NQR456W  04/08/2017
# 2             2    02-00-00            59 ST       NQR456W  04/08/2017
# 3             3    02-00-00            59 ST       NQR456W  04/08/2017
# 4             4    02-00-00            59 ST       NQR456W  04/08/2017
# 504         504    00-00-00       5 AV/59 ST          NQRW  04/08/2017
# 505         505    00-00-00       5 AV/59 ST          NQRW  04/08/2017
# 506         506    00-00-00       5 AV/59 ST          NQRW  04/08/2017
# 507         507    00-00-00       5 AV/59 ST          NQRW  04/08/2017
# 508         508    00-00-00       5 AV/59 ST          NQRW  04/08/2017
# 1091       1091    00-00-00       57 ST-7 AV          NQRW  04/08/2017
# 1092       1092    00-00-00       57 ST-7 AV          NQRW  04/08/2017
# 1093       1093    00-00-00       57 ST-7 AV          NQRW  04/08/2017
# 1094       1094    00-00-00       57 ST-7 AV          NQRW  04/08/2017
# 1095       1095    00-00-00       57 ST-7 AV          NQRW  04/08/2017
# 1679       1679    01-00-00            49 ST          NQRW  04/08/2017
# 1680       1680    01-00-00            49 ST          NQRW  04/08/2017
# 1681       1681    01-00-00            49 ST          NQRW  04/08/2017
# 1682       1682    01-00-00            49 ST          NQRW  04/08/2017
# 1683       1683    01-00-00            49 ST          NQRW  04/08/2017
# 2600       2600    01-00-00   TIMES SQ-42 ST  ACENQRS1237W  04/08/2017
# 2601       2601    01-00-00   TIMES SQ-42 ST  ACENQRS1237W  04/08/2017
# 2602       2602    01-00-00   TIMES SQ-42 ST  ACENQRS1237W  04/08/2017
# 2603       2603    01-00-00   TIMES SQ-42 ST  ACENQRS1237W  04/08/2017
# 2604       2604    01-00-00   TIMES SQ-42 ST  ACENQRS1237W  04/08/2017
# 2936       2936    01-00-00  34 ST-HERALD SQ      BDFMNQRW  04/08/2017
# 2937       2937    01-00-00  34 ST-HERALD SQ      BDFMNQRW  04/08/2017
# 2938       2938    01-00-00  34 ST-HERALD SQ      BDFMNQRW  04/08/2017
# 2939       2939    01-00-00  34 ST-HERALD SQ      BDFMNQRW  04/08/2017
# 2940       2940    01-00-00  34 ST-HERALD SQ      BDFMNQRW  04/08/2017
# ...         ...         ...              ...           ...         ...
# 200773   200773    00-00-00    RIT-MANHATTAN             R  04/08/2017
# 200774   200774    00-00-00    RIT-MANHATTAN             R  04/08/2017
# 200775   200775    00-00-00    RIT-MANHATTAN             R  04/08/2017
# 200776   200776    00-00-00    RIT-MANHATTAN             R  04/08/2017
# 200777   200777    00-00-00    RIT-MANHATTAN             R  04/08/2017
# 200945   200945    00-00-00    RIT-ROOSEVELT             R  04/08/2017
# 200946   200946    00-00-00    RIT-ROOSEVELT             R  04/08/2017
# 200947   200947    00-00-00    RIT-ROOSEVELT             R  04/08/2017
# 200948   200948    00-00-00    RIT-ROOSEVELT             R  04/08/2017
# 200949   200949    00-00-00    RIT-ROOSEVELT             R  04/08/2017
# 223535    22338    00-00-00            53 ST             R  03/25/2017
# 223536    22339    00-00-00            53 ST             R  03/25/2017
# 223537    22340    00-00-00            53 ST             R  03/25/2017
# 223538    22341    00-00-00            53 ST             R  03/25/2017
# 223539    22342    00-00-00            53 ST             R  03/25/2017
# 590618   191053    00-00-00  SUTTER AV-RUTLD             3  03/17/2018
# 590619   191054    00-00-00  SUTTER AV-RUTLD             3  03/17/2018
# 590620   191055    00-00-00  SUTTER AV-RUTLD             3  03/17/2018
# 590621   191056    00-00-00  SUTTER AV-RUTLD             3  03/17/2018
# 590622   191057    00-00-00  SUTTER AV-RUTLD             3  03/17/2018
# 591332   191767    00-00-00        JUNIUS ST             3  03/17/2018
# 591333   191768    00-00-00        JUNIUS ST             3  03/17/2018
# 591334   191769    00-00-00        JUNIUS ST             3  03/17/2018
# 591335   191770    00-00-00        JUNIUS ST             3  03/17/2018
# 591336   191771    00-00-00        JUNIUS ST             3  03/17/2018
# 1118536  127980    01-00-00    WTC-CORTLANDT             1  02/16/2019
# 1118537  127981    01-00-00    WTC-CORTLANDT             1  02/16/2019
# 1118538  127982    01-00-00    WTC-CORTLANDT             1  02/16/2019
# 1118539  127983    01-00-00    WTC-CORTLANDT             1  02/16/2019
# 1118540  127984    01-00-00    WTC-CORTLANDT             1  02/16/2019
#
#              time description  entry_cumulative  exit_cumulative  \
# 0        00:00:00     REGULAR           6127245          2076158
# 1        04:00:00     REGULAR           6127285          2076165
# 2        08:00:00     REGULAR           6127304          2076196
# 3        12:00:00     REGULAR           6127409          2076284
# 4        16:00:00     REGULAR           6127654          2076350
# 504      02:00:00     REGULAR           2775087          4752391
# 505      06:00:00     REGULAR           2775096          4752415
# 506      10:00:00     REGULAR           2775139          4752770
# 507      14:00:00     REGULAR           2775282          4753229
# 508      18:00:00     REGULAR           2775679          4753802
# 1091     00:00:00     REGULAR           2288728           910505
# 1092     04:00:00     REGULAR           2288861           910547
# 1093     08:00:00     REGULAR           2288928           910621
# 1094     12:00:00     REGULAR           2289239           910909
# 1095     16:00:00     REGULAR           2289866           911310
# 1679     00:00:00     REGULAR           5688773         34106506
# 1680     04:00:00     REGULAR           5688818         34106652
# 1681     08:00:00     REGULAR           5688837         34106825
# 1682     12:00:00     REGULAR           5688872         34107305
# 1683     16:00:00     REGULAR           5688927         34108163
# 2600     00:00:00     REGULAR           6598836          7765018
# 2601     04:00:00     REGULAR           6598915          7765082
# 2602     08:00:00     REGULAR           6598995          7765218
# 2603     12:00:00     REGULAR           6599236          7765858
# 2604     16:00:00     REGULAR           6599607          7766627
# 2936     00:00:00     REGULAR          23249624          9233391
# 2937     04:00:00     REGULAR          23249823          9233433
# 2938     08:00:00     REGULAR          23249874          9233505
# 2939     12:00:00     REGULAR          23250288          9233930
# 2940     16:00:00     REGULAR          23251241          9234585
# ...           ...         ...               ...              ...
# 200773   01:00:00     REGULAR            543780            10563
# 200774   05:00:00     REGULAR            543795            10565
# 200775   09:00:00     REGULAR            543821            10567
# 200776   13:00:00     REGULAR            544135            10571
# 200777   17:00:00     REGULAR            544867            10577
# 200945   01:00:00     REGULAR           3615367            50967
# 200946   05:00:00     REGULAR           3615371            50968
# 200947   09:00:00     REGULAR           3615446            50968
# 200948   13:00:00     REGULAR           3615931            50972
# 200949   17:00:00     REGULAR           3616517            50978
# 223535   00:00:00     REGULAR           9452466          4623625
# 223536   04:00:00     REGULAR           9452485          4623683
# 223537   08:00:00     REGULAR           9452693          4623766
# 223538   12:00:00     REGULAR           9453140          4623935
# 223539   16:00:00     REGULAR           9453476          4624123
# 590618   00:00:00     REGULAR          14173579          5038425
# 590619   04:00:00     REGULAR          14173602          5038450
# 590620   08:00:00     REGULAR          14173758          5038479
# 590621   12:00:00     REGULAR          14173972          5038590
# 590622   16:00:00     REGULAR          14174205          5038723
# 591332   00:00:00     REGULAR           4508980          1394033
# 591333   04:00:00     REGULAR           4508992          1394043
# 591334   08:00:00     REGULAR           4509035          1394057
# 591335   12:00:00     REGULAR           4509163          1394084
# 591336   16:00:00     REGULAR           4509312          1394122
# 1118536  00:00:00     REGULAR                21               13
# 1118537  04:00:00     REGULAR                21               13
# 1118538  08:00:00     REGULAR                21               13
# 1118539  12:00:00     REGULAR                21               13
# 1118540  16:00:00     REGULAR                21               13
#
#          entry_relative  exit_relative
# 0                   NaN            NaN
# 1                  40.0            7.0
# 2                  19.0           31.0
# 3                 105.0           88.0
# 4                 245.0           66.0
# 504          -4221883.0      4602715.0
# 505                 9.0           24.0
# 506                43.0          355.0
# 507               143.0          459.0
# 508               397.0          573.0
# 1091         -3926203.0     -1497422.0
# 1092              133.0           42.0
# 1093               67.0           74.0
# 1094              311.0          288.0
# 1095              627.0          401.0
# 1679          5278683.0     33708747.0
# 1680               45.0          146.0
# 1681               19.0          173.0
# 1682               35.0          480.0
# 1683               55.0          858.0
# 2600          6587716.0    -25831934.0
# 2601               79.0           64.0
# 2602               80.0          136.0
# 2603              241.0          640.0
# 2604              371.0          769.0
# 2936         21841287.0      6609767.0
# 2937              199.0           42.0
# 2938               51.0           72.0
# 2939              414.0          425.0
# 2940              953.0          655.0
# ...                 ...            ...
# 200773         543670.0        10563.0
# 200774             15.0            2.0
# 200775             26.0            2.0
# 200776            314.0            4.0
# 200777            732.0            6.0
# 200945        3613468.0        50967.0
# 200946              4.0            1.0
# 200947             75.0            0.0
# 200948            485.0            4.0
# 200949            586.0            6.0
# 223535        6733833.0      3964296.0
# 223536             19.0           58.0
# 223537            208.0           83.0
# 223538            447.0          169.0
# 223539            336.0          188.0
# 590618       14173577.0      5037545.0
# 590619             23.0           25.0
# 590620            156.0           29.0
# 590621            214.0          111.0
# 590622            233.0          133.0
# 591332        4031777.0       472327.0
# 591333             12.0           10.0
# 591334             43.0           14.0
# 591335            128.0           27.0
# 591336            149.0           38.0
# 1118536       -460826.0       -31225.0
# 1118537             0.0            0.0
# 1118538             0.0            0.0
# 1118539             0.0            0.0
# 1118540             0.0            0.0
#
# [1890 rows x 11 columns]

# %%
df_3=df[1:1000].groupby(['station','date','time']).diff().reset_index()
df_3
# Out:
#      level_0  index  entry_cumulative  exit_cumulative  entry_relative  \
# 0          1    NaN               NaN              NaN             NaN
# 1          2    NaN               NaN              NaN             NaN
# 2          3    NaN               NaN              NaN             NaN
# 3          4    NaN               NaN              NaN             NaN
# 4          5    NaN               NaN              NaN             NaN
# 5          6    NaN               NaN              NaN             NaN
# 6          7    NaN               NaN              NaN             NaN
# 7          8    NaN               NaN              NaN             NaN
# 8          9    NaN               NaN              NaN             NaN
# 9         10    NaN               NaN              NaN             NaN
# 10        11    NaN               NaN              NaN             NaN
# 11        12    NaN               NaN              NaN             NaN
# 12        13    NaN               NaN              NaN             NaN
# 13        14    NaN               NaN              NaN             NaN
# 14        15    NaN               NaN              NaN             NaN
# 15        16    NaN               NaN              NaN             NaN
# 16        17    NaN               NaN              NaN             NaN
# 17        18    NaN               NaN              NaN             NaN
# 18        19    NaN               NaN              NaN             NaN
# 19        20    NaN               NaN              NaN             NaN
# 20        21    NaN               NaN              NaN             NaN
# 21        22    NaN               NaN              NaN             NaN
# 22        23    NaN               NaN              NaN             NaN
# 23        24    NaN               NaN              NaN             NaN
# 24        25    NaN               NaN              NaN             NaN
# 25        26    NaN               NaN              NaN             NaN
# 26        27    NaN               NaN              NaN             NaN
# 27        28    NaN               NaN              NaN             NaN
# 28        29    NaN               NaN              NaN             NaN
# 29        30    NaN               NaN              NaN             NaN
# ..       ...    ...               ...              ...             ...
# 969      970   42.0       115233553.0       -5171321.0           109.0
# 970      971   42.0       115233663.0       -5171265.0           110.0
# 971      972   42.0       115233668.0       -5171266.0             5.0
# 972      973   42.0       115233693.0       -5171251.0            25.0
# 973      974   42.0       115233683.0       -5171003.0           -10.0
# 974      975   42.0       115233676.0       -5170695.0            -7.0
# 975      976   42.0       115233726.0       -5170578.0            50.0
# 976      977   42.0       115233820.0       -5170539.0            94.0
# 977      978   42.0       115233823.0       -5170541.0             3.0
# 978      979   42.0       115233854.0       -5169991.0            31.0
# 979      980   42.0       115233981.0       -5169702.0           127.0
# 980      981   42.0       115234292.0       -5169536.0           311.0
# 981      982   42.0       115234567.0       -5169384.0           275.0
# 982      983   42.0       115234658.0       -5169357.0            91.0
# 983      984   42.0       115234663.0       -5169357.0             5.0
# 984      985   42.0       115234686.0       -5168837.0            23.0
# 985      986   42.0       115234745.0       -5168532.0            59.0
# 986      987   42.0       115235093.0       -5168334.0           348.0
# 987      988   42.0       115235221.0       -5168156.0           128.0
# 988      989   42.0       115235334.0       -5168143.0           113.0
# 989      990   42.0       115235336.0       -5168141.0             2.0
# 990      991   42.0       115235348.0       -5167555.0            12.0
# 991      992   42.0       115235390.0       -5167293.0            42.0
# 992      993   42.0       115235451.0       -5167063.0            61.0
# 993      994   42.0       115235442.0       -5166913.0            -9.0
# 994      995   42.0       115235520.0       -5166866.0            78.0
# 995      996   42.0       115235525.0       -5166866.0             5.0
# 996      997   42.0       115235509.0       -5166371.0           -16.0
# 997      998   42.0       115235426.0       -5166038.0           -83.0
# 998      999   42.0       115235421.0       -5165817.0            -5.0
#
#      exit_relative
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 9              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 18             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 27             NaN
# 28             NaN
# 29             NaN
# ..             ...
# 969          112.0
# 970           56.0
# 971           -1.0
# 972           15.0
# 973          248.0
# 974          308.0
# 975          117.0
# 976           39.0
# 977           -2.0
# 978          550.0
# 979          289.0
# 980          166.0
# 981          152.0
# 982           27.0
# 983            0.0
# 984          520.0
# 985          305.0
# 986          198.0
# 987          178.0
# 988           13.0
# 989            2.0
# 990          586.0
# 991          262.0
# 992          230.0
# 993          150.0
# 994           47.0
# 995            0.0
# 996          495.0
# 997          333.0
# 998          221.0
#
# [999 rows x 6 columns]

# %%
df.loc[df['scp_address'] != df['scp_address']]

# %%
df['scp_address',1] == df['scp_address',2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('scp_address', 1)
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-61-dec3aa982f56> in <module>
# ----> 1 df['scp_address',1] == df['scp_address',2]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
# -> 2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2659         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2660         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('scp_address', 1)
